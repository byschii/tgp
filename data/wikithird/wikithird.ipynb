# %%
import requests
from bs4 import BeautifulSoup, Tag, NavigableString
import pandas as pd

base_url = "https://it.wikipedia.org/wiki/"

# grab  alist of fundamentalist wikis
lvl2 = f"{base_url}Wikipedia:Voci_fondamentali/Lista2"

# %%
def soup2urls(soup):
    content = soup.find("div", {"class": "mw-parser-output"})
    # remove the table of contents
    toc = content.find("div", {"class": "toc"})
    if toc: toc.decompose()
    
    # get all links
    links = content.find_all("a")
    # get the hrefs
    return [link.get("href") for link in links if link.get("href")]

def filter_urls(urls):
    to_remove = ["File", "Progetto", "Portale", "Speciale", "Categoria", "Wikipedia", "Aiuto", "Discussioni", "Templale", "Discussioni_progetto", "Discussioni_Wikipedia", "Template", "Utente", "Aiuto"]
    return set(filter(
        lambda h: not any([h.startswith(t+":") for t in to_remove]),
        urls)
        )

def soup2filtered_urls(soup, wikiprefix = "/wiki/"):
    try:
        hrefs = soup2urls(soup)
        hrefs = [href[len(wikiprefix) :] for href in hrefs if href.startswith(wikiprefix ) ]
        return filter_urls(hrefs)
    except:
        print("error for title" + soup.title.string)
        return set()

# %%
# decode url encoded characters
import urllib.parse
import re
import dataclasses


@dataclasses.dataclass
class Cleanupper:
    remove_index: bool = True
    remove_image: bool = True
    remove_h2: bool = True
    remove_h3: bool = True
    remove_h4: bool = True
    remove_double_space: bool = True
    remove_double_newline: bool = True
    remove_disambiguation: bool = True
    remove_see_also: bool = True
    remove_metadata_table: bool = True
    remove_inline_math: bool = True
    remove_quotes: bool = True
    remove_references_section: bool = True
    remove_cite: bool = True

    def remove_index_section(self, s: BeautifulSoup) -> BeautifulSoup:
        index = s.find('div', {'id': 'toc'})
        if index:
            s.find('div', {'id': 'toc'}).decompose()
        return s

    def __call__(self, s: Tag | NavigableString) -> str:        
        if self.remove_index:
            s = self.remove_index_section(s)
        if self.remove_image:
            for img in s.find_all('figure'):
                img.decompose()
        if self.remove_h2:
            for h2 in s.find_all('h2'):
                h2.decompose()
        if self.remove_h3:
            for h3 in s.find_all('h3'):
                h3.decompose()
        if self.remove_h4:
            for h4 in s.find_all('h4'):
                h4.decompose()
        if self.remove_disambiguation:
            for div in s.find_all('div', {"class": "nota-disambigua"}):
                div.decompose()
        if self.remove_see_also:
            for div in s.find_all('div', {"class": "vedi-anche"}):
                if div: div.decompose()
        if self.remove_metadata_table:
            for table in s.find_all('table', {"class": "metadata"}):
                table.decompose()
        if self.remove_inline_math:
            for math in s.find_all('span', {"class": "mwe-math-element"}):
                math.decompose()
        if self.remove_references_section:
            for section in s.find_all('ol', {"class": "references"}):
                section.decompose()
        if self.remove_cite:
            for cite in s.find_all('cite'):
                cite.decompose()

        text = s.text
        if self.remove_double_space:
            text = re.sub(r'\s\s+', ' ', text)
        if self.remove_double_newline:
            text = re.sub(r'\n\n+', '\n', text)
        if self.remove_quotes: # number between []
            text = re.sub(r'\[\d+\]', '', text)


        return text
    
def decode_url(url: str) -> str:
    return urllib.parse.unquote(url).replace("/", "_")

# %%
# kinda scraper
def soup2text(soup, cleanupper: Cleanupper = Cleanupper()) -> str:
    content = soup.find("div", {"class": "mw-parser-output"})
    return cleanupper(content)


def url2soup(url: str) -> BeautifulSoup:
    r = requests.get(url)
    return BeautifulSoup(r.text, "html.parser")

# %%
import os 
import time
import random


def read_and_download_soup(soup, url, min_page_len=5_000):
    try:
        text = soup2text(soup)
        if len(text) < min_page_len:
            return False 

        with open(f"pages/{decode_url(url)}.txt", 'w+') as f:
            f.write(text)
    except:
        return False

    return True

# initial urls 
initial_urls = soup2filtered_urls(url2soup(lvl2))

os.makedirs("pages", exist_ok=True)
done = set(os.listdir("pages"))

# download recursively
# kinda scraper 
def downlaod_pages(source_urls, level=0, max_level=3, min_page_len=5_000, wait_time=2):
    random.shuffle(source_urls)
    for url in source_urls:
        already_done = decode_url(url) in done
        print(f"level {level} - {'V' if already_done else '?'} - {decode_url(url)}")
        if decode_url(url) in done:
            continue
    
        if wait_time > 0:
            time.sleep(random.random() * wait_time)

        soup = url2soup(f"{base_url}{url}")
        if read_and_download_soup(soup, url, min_page_len=min_page_len):
            done.add(decode_url(url))    

        if level < max_level:
            downlaod_pages(list(soup2filtered_urls(soup)), level=level+1)


downlaod_pages(list(initial_urls))
# Out:
# level 0 - ? - Broadcasting
# level 1 - ? - Internet_Protocol
# level 2 - ? - Commutazione_(telecomunicazioni)
# level 3 - ? - Telecomunicazioni
# level 3 - ? - ISO_OSI
# level 3 - ? - Teoria_dei_segnali
# level 3 - ? - Commutatore_(telecomunicazioni)
# level 3 - ? - Rete_di_telecomunicazioni
# level 3 - ? - Telefonia
# level 3 - ? - Robustezza_(informatica)
# level 3 - ? - Multiplazione
# level 3 - ? - Canale_(telecomunicazioni)
# level 3 - ? - Livello_di_rete
# level 3 - ? - Video
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Multiplazione#Multiplazione_statistica
# level 3 - ? - Commutazione_di_pacchetto
# level 3 - ? - Banda_(informatica)
# level 3 - ? - Qualità_di_servizio
# level 3 - ? - Cavo_elettrico
# level 3 - ? - Architettura_di_rete
# level 3 - ? - Rete_di_computer
# level 3 - ? - Circuito_virtuale
# level 3 - ? - Trasmissione_(telecomunicazioni)
# level 3 - ? - Fibra_ottica
# level 3 - ? - Instradamento
# level 3 - ? - File
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Commutazione_a_circuito
# level 3 - ? - Velocità
# level 3 - ? - Centro_studi_e_laboratori_telecomunicazioni
# level 3 - ? - Informazione
# level 3 - ? - Commutazione_di_circuito
# level 2 - ? - Scheda_di_rete
# level 3 - ? - Hotspot_(telematica)
# level 3 - ? - D-Link
# level 3 - ? - Broadcom
# level 3 - ? - Realtek
# level 3 - ? - Elettronica
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - ? - Access_point
# level 3 - ? - Digitale_(informatica)
# level 3 - ? - Indirizzo_IP
# level 3 - ? - 3Com
# level 3 - ? - Onde_radio
# level 3 - ? - Token_bus
# level 3 - ? - Ethernet
# level 3 - ? - Antenna
# level 3 - ? - Connessione_(informatica)
# level 3 - ? - Informatica
# level 3 - ? - Qualcomm
# level 3 - ? - Novell
# level 3 - ? - Wireless
# level 3 - ? - Scheda_elettronica
# level 3 - ? - Wi-Fi
# level 3 - ? - Punto_di_accesso
# level 3 - ? - PC
# level 3 - ? - Token_ring
# level 3 - ? - Laptop
# level 3 - ? - Rete_informatica
# level 3 - ? - Indirizzo_MAC
# level 3 - ? - Intel
# level 3 - ? - Lingua_inglese
# level 3 - ? - Interfaccia_(informatica)
# level 3 - ? - Bluetooth
# level 2 - ? - Routing_table
# level 3 - ? - RAM
# level 3 - ? - Host
# level 3 - ? - Subnet
# level 3 - ? - Reverse_path_forwarding
# level 3 - ? - Carta_geografica
# level 3 - ? - Control_plane
# level 3 - ? - IPv4
# level 3 - ? - Topologia_di_rete
# level 3 - ? - Supernetting
# level 3 - ? - Protocolli_di_routing
# level 3 - ? - Denial_of_service
# level 3 - ? - VDSL2
# level 3 - ? - Supernetting#CIDR
# level 3 - V - Informatica
# level 3 - ? - Forwarding_information_base
# level 3 - ? - Access_control_list
# level 3 - ? - Instradamento_statico
# level 3 - ? - Servizio_postale
# level 3 - ? - Router
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Tabella
# level 3 - ? - Protocollo_di_routing#Algoritmi_adattivi
# level 3 - ? - Home_Access_Gateway
# level 2 - ? - IP_spoofing
# level 3 - ? - Python
# level 3 - ? - Socket
# level 3 - V - Internet_Protocol
# level 3 - ? - Password
# level 3 - ? - X_Window_System
# level 3 - ? - ACK_(informatica)
# level 3 - ? - Remote_Procedure_Call
# level 3 - ? - C++
# level 3 - ? - Intranet
# level 3 - ? - Username
# level 3 - ? - Autenticazione
# level 3 - ? - Modalità_promiscua
# level 3 - ? - Sliding_window
# level 3 - V - Denial_of_service
# level 3 - ? - Unix
# level 3 - ? - DoS#DDoS
# level 3 - ? - C_(linguaggio)
# level 3 - ? - SYN_flood
# level 3 - ? - Rete_satellitare
# level 3 - ? - Smurf
# level 3 - ? - Spoofing
# level 3 - ? - Latenza
# level 3 - ? - Host
# level 3 - ? - Transmission_Control_Protocol
# level 3 - ? - User_Datagram_Protocol
# level 3 - ? - Header
# level 3 - ? - Internet
# level 3 - V - Rete_di_computer
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Attacco_informatico
# level 3 - V - Indirizzo_IP
# level 3 - ? - Routing
# level 3 - ? - Firewall
# level 3 - ? - Denial_of_Service
# level 3 - ? - IPsec
# level 2 - ? - Scalabilità
# level 3 - ? - Risorsa_informatica
# level 3 - ? - Gemeinsame_Normdatei
# level 3 - ? - O-grande
# level 3 - ? - Sistema_distribuito
# level 3 - ? - Online_transaction_processing
# level 3 - ? - Progettazione_(ingegneria_del_software)
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Hardware
# level 3 - V - Telecomunicazioni
# level 3 - ? - Ingegneria_del_software
# level 3 - V - Informatica
# level 3 - ? - CPU
# level 3 - ? - Necessità
# level 3 - ? - Legge_di_Amdahl
# level 3 - ? - Materia_(didattica)
# level 3 - ? - Protocollo_di_routing
# level 3 - ? - Throughput
# level 3 - ? - Collo_di_bottiglia_(ingegneria)
# level 3 - ? - Utilità
# level 3 - V - Rete_di_computer
# level 3 - ? - Architettura_software
# level 3 - ? - Disponibilità
# level 3 - ? - Database_management_system
# level 3 - ? - Memoria_(informatica)
# level 3 - ? - Instruction_level_parallelism
# level 3 - ? - Architettura_hardware
# level 3 - ? - Load_balancing
# level 3 - ? - Usabilità
# level 3 - ? - Tabella_di_routing
# level 2 - ? - Modello_ISO_OSI
# level 3 - ? - Banda_ultralarga
# level 3 - ? - Finger_(Unix)
# level 3 - ? - Internet_Relay_Chat
# level 3 - ? - File_Transfer_Protocol
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Instradamento#Routing
# level 3 - ? - Bit
# level 3 - ? - Sistema_informatico
# level 3 - ? - Internetwork_Packet_Exchange
# level 3 - ? - Livello_di_accesso_alla_rete
# level 3 - ? - Livello_di_applicazione
# level 3 - ? - Maximum_Transmission_Unit
# level 3 - ? - Crittografia
# level 3 - V - Connessione_(informatica)
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Asynchronous_Transfer_Mode
# level 3 - ? - ASCII
# level 3 - ? - Controllo_di_flusso
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - Bridge_(informatica)
# level 3 - ? - Service_Access_Point
# level 3 - V - Hardware
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - ? - Livello_di_collegamento_dati
# level 3 - ? - Optical_Transport_Network
# level 3 - ? - DSL
# level 3 - ? - Management_di_rete
# level 3 - ? - X.25
# level 3 - ? - Controllo_della_congestione
# level 3 - ? - Internet_Message_Access_Protocol
# level 3 - V - Fibra_ottica
# level 3 - V - Cavo_elettrico
# level 3 - ? - ACK_(informatica)
# level 3 - V - Informazione
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Livello_di_rete
# level 3 - ? - NetBIOS
# level 3 - ? - Tensione_elettrica
# level 3 - ? - Cross-layer
# level 3 - ? - Telnet
# level 3 - ? - SOCKS
# level 3 - ? - Terminale_virtuale
# level 3 - ? - Multipurpose_Internet_Mail_Extensions
# level 3 - ? - Dynamic_Host_Configuration_Protocol
# level 3 - ? - Organizzazione_Internazionale_per_le_Standardizzazioni
# level 3 - ? - Logical_link_control
# level 3 - ? - Newsgroup
# level 3 - V - Rete_di_computer
# level 3 - ? - Modulazione
# level 3 - ? - Radiocomunicazione
# level 3 - ? - Codifica
# level 3 - V - Routing_table
# level 3 - ? - Token_(testo)
# level 3 - ? - Network_News_Transfer_Protocol
# level 3 - ? - Secure_Shell
# level 3 - V - Internet
# level 3 - ? - Rilevazione_e_correzione_d'errore
# level 3 - ? - Velocità_di_trasmissione
# level 3 - ? - ISO_7498
# level 3 - ? - Rete_di_telecomunicazione
# level 3 - ? - Media_Access_Control
# level 3 - ? - Data_frame
# level 3 - ? - Duplex
# level 3 - ? - Implementazione
# level 3 - ? - Livello_di_presentazione
# level 3 - ? - Protocolli_di_routing
# level 3 - ? - Scheda_di_rete
# level 3 - ? - Interfaccia_video#Tipi_di_connettori
# level 3 - V - Commutazione_di_pacchetto
# level 3 - ? - Algoritmo
# level 3 - ? - Livello_di_sessione
# level 3 - ? - TCP_IP
# level 3 - ? - Simple_Mail_Transfer_Protocol
# level 3 - V - Ethernet
# level 3 - ? - Domain_Name_System
# level 3 - ? - Switch
# level 3 - ? - E-mail
# level 3 - ? - Mezzo_trasmissivo
# level 3 - ? - Hub_(informatica)
# level 3 - ? - Open_Systems_Interconnection
# level 3 - ? - Network_Time_Protocol
# level 3 - V - Rete_di_telecomunicazioni
# level 3 - V - Wi-Fi
# level 3 - ? - 1984
# level 3 - ? - Progettazione
# level 3 - ? - Formato_aperto
# level 3 - ? - Post_Office_Protocol
# level 3 - V - Architettura_di_rete
# level 3 - ? - Livello_fisico
# level 3 - ? - Applicazione_(informatica)
# level 3 - ? - Lightweight_Directory_Access_Protocol
# level 3 - ? - Gateway_(informatica)
# level 3 - ? - Host
# level 3 - ? - Pretty_Good_Privacy
# level 3 - V - File
# level 3 - ? - Imbustamento
# level 3 - ? - Linea_di_trasmissione
# level 3 - ? - User_Datagram_Protocol
# level 3 - ? - Simple_Network_Management_Protocol
# level 3 - ? - Gnutella
# level 3 - ? - Modem
# level 3 - ? - Standard_(informatica)
# level 3 - ? - Header
# level 3 - ? - Computer
# level 3 - ? - Livello_di_trasporto
# level 3 - V - Unix
# level 3 - ? - Protocollo_di_rete
# level 3 - ? - Controllo_di_errore
# level 3 - ? - Telecomunicazione
# level 3 - V - Token_ring
# level 3 - ? - ARPAnet
# level 3 - ? - Compressione_dati
# level 3 - V - Transmission_Control_Protocol
# level 3 - V - Bluetooth
# level 3 - ? - Hypertext_Transfer_Protocol
# level 3 - ? - FDDI
# level 3 - ? - De_facto
# level 3 - V - Router
# level 3 - ? - Point-to-Point_Protocol
# level 3 - ? - Segnale_(fisica)
# level 3 - ? - International_Organization_for_Standardization
# level 3 - V - Instradamento
# level 3 - ? - RS-232
# level 3 - ? - Posta_elettronica
# level 3 - ? - Onda_radio
# level 3 - V - Informatica
# level 3 - V - Internet_Protocol
# level 3 - V - Telecomunicazioni
# level 2 - V - Gemeinsame_Normdatei
# level 2 - ? - Token_bus
# level 3 - ? - Rete_ad_anello
# level 3 - V - Protocollo_di_rete
# level 3 - V - Token_ring
# level 3 - ? - TDMA
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Rete_di_calcolatori
# level 3 - V - Computer
# level 3 - ? - Bus_(informatica)
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Accesso_multiplo
# level 3 - V - Telecomunicazioni
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - Local_area_network
# level 3 - ? - IEEE_802.4
# level 2 - ? - Nodo_(informatica)
# level 3 - V - Telecomunicazioni
# level 3 - ? - Teoria_dei_grafi
# level 3 - ? - Rete_di_trasporto
# level 3 - ? - Scheda_di_rete
# level 3 - ? - Commutazione_(telecomunicazioni)
# level 3 - ? - Client
# level 3 - ? - Arco_(teoria_dei_grafi)
# level 3 - V - Connessione_(informatica)
# level 3 - ? - Stampante
# level 3 - ? - Communication_endpoint
# level 3 - ? - Reti_di_telecomunicazioni
# level 3 - ? - Fax
# level 3 - ? - Vertice_(teoria_dei_grafi)
# level 3 - V - Modem
# level 3 - ? - Grafo
# level 3 - V - Informatica
# level 3 - ? - Server
# level 3 - V - Segnale_(fisica)
# level 3 - V - Computer
# level 3 - ? - Host
# level 3 - V - Hardware
# level 3 - V - Hub_(informatica)
# level 3 - V - Instradamento
# level 3 - V - Topologia_di_rete
# level 2 - V - Indirizzo_IP
# level 2 - V - Interfaccia_(informatica)
# level 2 - ? - Protocol_Data_Unit
# level 3 - V - Organizzazione_Internazionale_per_le_Standardizzazioni
# level 3 - V - Bit
# level 3 - V - ISO_OSI
# level 3 - ? - Livello_applicazioni
# level 3 - ? - Livello_di_sessione
# level 3 - ? - Livello_di_rete
# level 3 - ? - Livello_datalink
# level 3 - ? - Livello_di_presentazione
# level 3 - V - Protocollo_di_rete
# level 3 - ? - Livello_di_trasporto
# level 3 - V - Architettura_di_rete
# level 3 - ? - Protocollo_di_comunicazione
# level 3 - ? - Service_Data_Unit
# level 3 - ? - Sessione
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Informazione
# level 3 - ? - Livello_fisico
# level 2 - ? - Carico_utile_(informatica)
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Reti_di_calcolatori
# level 3 - ? - Trigger_(informatica)
# level 3 - V - Livello_datalink
# level 3 - ? - Funzione_(informatica)
# level 3 - ? - Trasporti
# level 3 - ? - Worm
# level 3 - ? - Programmazione_(informatica)
# level 3 - ? - Lista_di_formati_di_file#File_compressi_e_archivi
# level 3 - ? - Sicurezza_informatica
# level 3 - ? - Metadati
# level 3 - ? - Web_service
# level 3 - ? - Virus_(informatica)
# level 3 - ? - Header
# level 3 - V - Rete_di_telecomunicazione
# level 3 - ? - Frame_Ethernet
# level 3 - ? - Checksum
# level 3 - ? - Malware
# level 3 - ? - JSON
# level 3 - ? - Protocollo_di_comunicazione
# level 3 - ? - Overhead
# level 3 - ? - Trasmissione_digitale
# level 3 - V - Informazione
# level 3 - ? - Livello_di_rete
# level 3 - ? - Carico_utile
# level 2 - ? - Rete_internet
# level 3 - ? - Apparato_di_rete
# level 3 - V - Newsgroup
# level 3 - ? - Doppino_telefonico
# level 3 - ? - Governo_Berlusconi_IV
# level 3 - V - Modem
# level 3 - ? - Utente
# level 3 - ? - DHCP
# level 3 - ? - Vinton_Cerf
# level 3 - ? - Ricetrasmettitore
# level 3 - ? - Regno_Unito
# level 3 - ? - Democrazia
# level 3 - ? - Internet_Engineering_Steering_Group
# level 3 - ? - Spam
# level 3 - ? - Revisione_paritaria
# level 3 - ? - Reti_di_computer
# level 3 - V - Denial_of_Service
# level 3 - ? - Global_Positioning_System
# level 3 - ? - Dipendenza
# level 3 - ? - Gopher_(informatica)
# level 3 - ? - Edward_Snowden
# level 3 - ? - Antonomasia
# level 3 - ? - Online_e_offline
# level 3 - V - DSL
# level 3 - ? - GPRS
# level 3 - ? - Lingue_di_Internet
# level 3 - ? - Hosting
# level 3 - ? - IPTV
# level 3 - ? - IBM
# level 3 - ? - Ray_Tomlinson
# level 3 - ? - Dispositivi_di_rete
# level 3 - ? - Comunità_scientifica
# level 3 - ? - Banda_(informatica)
# level 3 - ? - Header
# level 3 - ? - Storia_di_Internet
# level 3 - ? - Protocolli_di_rete
# level 3 - V - File_Transfer_Protocol
# level 3 - ? - Robert_Cailliau
# level 3 - ? - Bolla_delle_dot-com
# level 3 - ? - E-Learning
# level 3 - V - Firewall
# level 3 - ? - Guerra_fredda
# level 3 - ? - Stati_Uniti_d'America
# level 3 - ? - Egitto
# level 3 - ? - Truffa
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - ? - Livello_applicazioni
# level 3 - ? - Host
# level 3 - ? - Cloud_computing
# level 3 - V - Intranet
# level 3 - ? - HDSL
# level 3 - ? - Nicolas_Sarkozy
# level 3 - ? - Next_Generation_Network
# level 3 - ? - E-Government
# level 3 - V - Rete_di_telecomunicazione
# level 3 - V - Sistema_informatico
# level 3 - ? - Locuzione
# level 3 - ? - Google
# level 3 - V - Hardware
# level 3 - ? - Internet_Architecture_Board
# level 3 - ? - UMTS
# level 3 - ? - Unione_Sovietica
# level 3 - ? - Nicholas_Carr
# level 3 - ? - 1998
# level 3 - ? - ONU
# level 3 - ? - Honeywell
# level 3 - ? - Content_Delivery_Network
# level 3 - ? - Televisione
# level 3 - ? - Los_Angeles
# level 3 - ? - E-Mail
# level 3 - ? - Browser
# level 3 - ? - Collo_di_bottiglia_(ingegneria)
# level 3 - ? - Wide_Area_Network
# level 3 - ? - POTS
# level 3 - V - Posta_elettronica
# level 3 - ? - Portale_web
# level 3 - V - Video
# level 3 - V - Fibra_ottica
# level 3 - ? - Commercio
# level 3 - ? - Implementazione
# level 3 - ? - Rete_telefonica_generale
# level 3 - V - Transmission_Control_Protocol
# level 3 - ? - Bitcoin
# level 3 - V - Telnet
# level 3 - ? - Think_tank
# level 3 - ? - Peer-to-peer
# level 3 - ? - Secondo_mondo
# level 3 - V - Cavo_elettrico
# level 3 - V - Commutazione_di_pacchetto
# level 3 - ? - Sicurezza_pubblica
# level 3 - ? - Traffico_(telecomunicazioni)
# level 3 - V - Architettura_di_rete
# level 3 - ? - Dorsale_(informatica)
# level 3 - ? - Diritto_all'oblio
# level 3 - ? - V.90
# level 3 - ? - Microprocessore
# level 3 - V - Sistema_distribuito
# level 3 - ? - Pedofilia
# level 3 - ? - Evgeny_Morozov
# level 3 - ? - Mondo_occidentale
# level 3 - ? - Europa
# level 3 - ? - Mailing_list
# level 3 - ? - Liberalizzazione
# level 3 - ? - 1991
# level 3 - ? - Gateway_(informatica)
# level 3 - ? - Elaboratore_elettronico
# level 3 - ? - Sito_web
# level 3 - ? - Statistica
# level 3 - ? - CERN
# level 3 - ? - Diritto_d'autore
# level 3 - ? - Internet2
# level 3 - ? - LinkedIn
# level 3 - ? - Library_of_Congress_Control_Number
# level 3 - ? - Overhead
# level 3 - ? - Luca_De_Biase
# level 3 - ? - Rete_sociale
# level 3 - V - Rete_satellitare
# level 3 - V - Malware
# level 3 - ? - Globalizzazione
# level 3 - V - Lingua_inglese
# level 3 - ? - Anarchia
# level 3 - ? - Persona_fisica
# level 3 - ? - Elisabetta_II_del_Regno_Unito
# level 3 - ? - De_facto
# level 3 - ? - Cina
# level 3 - V - ISO_OSI
# level 3 - ? - Cyberbullismo
# level 3 - ? - Ricerca_scientifica
# level 3 - ? - Joseph_Licklider
# level 3 - ? - Multimedialità
# level 3 - ? - Invenzione
# level 3 - V - TCP_IP
# level 3 - ? - ISOC
# level 3 - ? - Tablet_computer
# level 3 - ? - Privacy
# level 3 - V - Connessione_(informatica)
# level 3 - ? - Banda_larga
# level 3 - ? - Lingua_italiana
# level 3 - ? - Iran
# level 3 - V - Rete_di_trasporto
# level 3 - ? - Architettura_(computer)
# level 3 - ? - Software
# level 3 - ? - Internet_dipendenza
# level 3 - ? - Servizio_universale
# level 3 - ? - Collegamento_ipertestuale
# level 3 - ? - Webcast
# level 3 - V - Password
# level 3 - ? - Palmare
# level 3 - V - Informazione
# level 3 - ? - Amministratore_di_rete
# level 3 - ? - Marketing
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - V - Wireless
# level 3 - ? - User-friendly
# level 3 - ? - Ginevra
# level 3 - ? - Diritto_civile
# level 3 - ? - Audio
# level 3 - ? - Attacco_nucleare
# level 3 - ? - VOIP
# level 3 - V - Computer
# level 3 - ? - PRISM_(programma_di_sorveglianza)
# level 3 - ? - Pornografia
# level 3 - ? - Link_di_comunicazione
# level 3 - ? - Mezzo_di_comunicazione_di_massa
# level 3 - ? - Twitter
# level 3 - ? - Radiofrequenza
# level 3 - ? - Dizionario_Internet
# level 3 - ? - Commutazione_(telecomunicazioni)
# level 3 - ? - Francia
# level 3 - ? - Cablaggio
# level 3 - V - Hypertext_Transfer_Protocol
# level 3 - ? - Scienza_dei_dati
# level 3 - ? - Emoticon
# level 3 - ? - Mezzo_trasmissivo
# level 3 - ? - ISDN
# level 3 - ? - E-Commerce
# level 3 - ? - ARPANET
# level 3 - ? - Massachusetts_Institute_of_Technology
# level 3 - ? - Dipendenza_da_internet
# level 3 - ? - Università_di_Pisa
# level 3 - ? - Stavros_Lambrinidis
# level 3 - ? - E-Democracy
# level 3 - ? - DARPA
# level 3 - ? - Preservazione_digitale
# level 3 - ? - IPv6
# level 3 - V - Indirizzo_IP
# level 3 - ? - Terminale_(informatica)
# level 3 - ? - Socket_(reti)
# level 3 - V - Standard_(informatica)
# level 3 - V - Informatica
# level 3 - ? - Copyright
# level 3 - ? - Cavo_coassiale
# level 3 - ? - IANA
# level 3 - ? - Cavi_sottomarini
# level 3 - ? - ICANN
# level 3 - ? - Social_network
# level 3 - ? - Forum_(Internet)
# level 3 - ? - World_Wide_Web_Consortium
# level 3 - V - Wi-Fi
# level 3 - ? - Livello_fisico
# level 3 - ? - Internet_delle_cose
# level 3 - ? - Centro_Nazionale_Universitario_di_Calcolo_Elettronico
# level 3 - ? - Podcast
# level 3 - V - Compressione_dati
# level 3 - ? - Dave_Eggers
# level 3 - ? - Request_for_Comments
# level 3 - ? - Rete_locale
# level 3 - ? - Time-sharing
# level 3 - ? - Pubblicità
# level 3 - ? - Diritto_di_accesso_a_Internet
# level 3 - ? - Client
# level 3 - ? - Robert_Kahn
# level 3 - ? - Metropolitan_Area_Network
# level 3 - ? - Infodemiologia
# level 3 - ? - Linea_telefonica
# level 3 - V - Router
# level 3 - ? - Jaron_Lanier
# level 3 - V - Instradamento
# level 3 - V - Domain_Name_System
# level 3 - ? - Infranet
# level 3 - ? - Ipertesto
# level 3 - ? - Condanna
# level 3 - ? - Neutralità_della_rete
# level 3 - V - Rete_di_telecomunicazioni
# level 3 - ? - Articolo_(giornalismo)
# level 3 - ? - Client-server
# level 3 - ? - Arpanet
# level 3 - ? - Imbustamento
# level 3 - ? - Tim_Berners-Lee
# level 3 - ? - Local_Area_Network
# level 3 - ? - E-commerce
# level 3 - V - Sessione
# level 3 - ? - 1971
# level 3 - ? - Correlazione_(statistica)
# level 3 - ? - Sviluppo_economico
# level 3 - ? - Chat
# level 3 - ? - Multiplayer
# level 3 - ? - User_Datagram_Protocol
# level 3 - ? - Dipartimento_della_Difesa_degli_Stati_Uniti
# level 3 - ? - File_sharing
# level 3 - ? - Linea_di_telecomunicazione
# level 3 - ? - Piccola_e_media_impresa
# level 3 - ? - ADSL
# level 3 - ? - Facebook
# level 3 - ? - 1969
# level 3 - ? - URL
# level 3 - ? - Geert_Lovink
# level 3 - ? - Information_and_Communications_Technology
# level 3 - ? - Biblioteca_della_Dieta_nazionale_del_Giappone
# level 3 - ? - World_Wide_Web
# level 3 - ? - New_Economy
# level 3 - V - Velocità_di_trasmissione
# level 3 - ? - Home_banking
# level 3 - ? - VDSL
# level 3 - ? - Internet_Engineering_Task_Force
# level 3 - ? - Web_radio
# level 3 - ? - Online
# level 3 - ? - Burocrazia
# level 3 - V - Internet_Protocol
# level 3 - ? - Stato
# level 3 - ? - VoIP
# level 3 - ? - Germania
# level 3 - ? - Sistema_embedded
# level 3 - ? - Video_sharing
# level 3 - ? - Terzo_mondo
# level 3 - ? - Rete_telefonica
# level 3 - ? - The_Guardian
# level 3 - ? - FBI
# level 3 - ? - Anni_1960
# level 3 - ? - Primavera_araba
# level 3 - V - File
# level 3 - ? - Norvegia
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - E-health
# level 3 - ? - Biblioteca_nazionale_di_Spagna
# level 3 - V - Sicurezza_informatica
# level 3 - ? - W3C
# level 3 - ? - Internet_Service_Provider
# level 3 - ? - 1962
# level 3 - ? - High-Speed_Downlink_Packet_Access
# level 3 - ? - 1963
# level 3 - ? - Indagine_di_mercato
# level 3 - ? - Disinformazione
# level 3 - ? - YouTube
# level 3 - ? - GSM
# level 3 - ? - Rete_quantistica
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Kbps
# level 3 - ? - Metanetwork
# level 3 - ? - Cella_radio
# level 3 - ? - Elaborazione_dati
# level 3 - ? - Suite_di_protocolli_Internet
# level 3 - V - Topologia_di_rete
# level 3 - ? - Louis_Pouzin
# level 3 - ? - Pubblicazione_scientifica
# level 3 - ? - Livello_di_trasporto
# level 3 - ? - Nuovo_soggettario
# level 3 - ? - Telefono_cellulare
# level 3 - ? - Motori_di_ricerca
# level 3 - ? - Congestione_(reti)
# level 3 - ? - Lex_informatica
# level 3 - ? - Londra
# level 3 - ? - Web_Tv
# level 3 - ? - Utah
# level 3 - ? - Cracker_(informatica)
# level 3 - ? - Tim_Berners_Lee
# level 3 - ? - Ponte_radio
# level 3 - ? - File_hosting
# level 3 - ? - WiFi
# level 3 - ? - Didattica
# level 3 - ? - Blog
# level 3 - ? - Terrorismo
# level 3 - ? - Sistema_operativo
# level 3 - ? - Tunisia
# level 3 - ? - Mondo_sviluppato
# level 3 - ? - Voip
# level 3 - ? - Porta_(reti)
# level 3 - ? - Livello_di_rete
# level 3 - ? - Tecnologia
# level 3 - ? - Unione_europea
# level 3 - ? - Business
# level 3 - ? - Gabriella_Carlucci
# level 3 - ? - Internet_Archive
# level 3 - ? - Interoperabilità
# level 3 - ? - Immagine_digitale
# level 3 - ? - Psichiatra
# level 3 - V - Risorsa_informatica
# level 3 - V - Server
# level 3 - ? - Mosaic
# level 3 - V - E-mail
# level 3 - ? - The_Washington_Post
# level 3 - ? - Comunicazione_di_massa
# level 3 - ? - Ridondanza_(ingegneria)
# level 3 - ? - Anni_1990
# level 3 - ? - Web_browser
# level 3 - ? - Rete_di_accesso
# level 3 - ? - Carta_di_credito
# level 3 - ? - Italia
# level 3 - V - Protocollo_di_rete
# level 3 - V - Autenticazione
# level 3 - ? - Carnivore_(software)
# level 3 - ? - Apprendimento
# level 3 - ? - Network_address_translation
# level 3 - ? - Carico_utile_(informatica)
# level 3 - ? - Biblioteca_nazionale_di_Francia
# level 3 - ? - Conoscenza
# level 3 - ? - Dispositivo_mobile
# level 3 - ? - Garanzia
# level 3 - V - Multiplazione
# level 3 - ? - Libertà_di_espressione
# level 3 - V - Commutazione_di_circuito
# level 3 - ? - Censura_di_Internet
# level 3 - ? - Diritto
# level 3 - ? - Web_invisibile
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Radio_(mass_media)
# level 3 - ? - Autostrada_dell'informazione
# level 3 - ? - Ampiezza_di_banda
# level 3 - ? - Streaming
# level 2 - V - Internet
# level 2 - ? - Interoperabilità
# level 3 - ? - Linguaggio_di_programmazione
# level 3 - ? - Architettura_dell'informazione
# level 3 - V - Telefono_cellulare
# level 3 - V - Informatica
# level 3 - V - Telecomunicazioni
# level 3 - ? - Internal_vision
# level 3 - V - Rete_telefonica
# level 3 - V - ADSL
# level 3 - ? - Web
# level 3 - ? - E-government
# level 3 - V - Telefonia
# level 3 - ? - Trasporto_ferroviario
# level 3 - ? - Rete_senza_fili
# level 3 - ? - Piattaforma_(informatica)
# level 3 - V - Web_service
# level 3 - ? - Sinergia
# level 3 - ? - Protocollo_(informatica)
# level 3 - ? - Portabilità
# level 3 - V - Hardware
# level 3 - ? - Codice_sorgente
# level 3 - ? - ERTMS
# level 3 - ? - Digital_Mobile_Radio
# level 3 - ? - Wireless_Application_Protocol
# level 3 - V - UMTS
# level 3 - V - Internet
# level 3 - ? - Sicurezza_stradale
# level 3 - ? - TETRA
# level 3 - ? - Web_Services_Interoperability
# level 3 - ? - Satellite_artificiale
# level 3 - V - Software
# level 3 - V - Nuovo_soggettario
# level 3 - ? - Formato_aperto
# level 3 - V - GPRS
# level 3 - ? - Codice_oggetto
# level 3 - ? - Doppino
# level 3 - ? - Trasporto_aereo
# level 2 - ? - DNS
# level 3 - ? - DNSSEC
# level 3 - ? - Paul_Mockapetris
# level 3 - ? - Cache
# level 3 - V - Telnet
# level 3 - V - Stati_Uniti_d'America
# level 3 - ? - World_wide_web
# level 3 - V - Router
# level 3 - V - Europa
# level 3 - ? - Client
# level 3 - V - E-mail
# level 3 - ? - Association_for_Computing_Machinery
# level 3 - ? - Record_TXT
# level 3 - V - Telecomunicazioni
# level 3 - ? - Unicode
# level 3 - ? - Root_nameserver
# level 3 - V - Informatica
# level 3 - V - Malware
# level 3 - ? - Record_NS
# level 3 - ? - Punycode
# level 3 - ? - 1983
# level 3 - V - Network_address_translation
# level 3 - ? - 1987
# level 3 - ? - Whois
# level 3 - ? - IANA
# level 3 - V - ADSL
# level 3 - ? - Demone_(informatica)
# level 3 - ? - Tipi_di_record_DNS
# level 3 - ? - Reato
# level 3 - V - Software
# level 3 - ? - User_Datagram_Protocol
# level 3 - ? - Record_AAAA
# level 3 - V - Porta_(reti)
# level 3 - ? - Risoluzione_DNS_inversa
# level 3 - ? - Virtual_hosting
# level 3 - ? - Google_Public_DNS
# level 3 - ? - Proxy
# level 3 - ? - Database
# level 3 - V - ASCII
# level 3 - ? - Biblioteca_della_Dieta_nazionale_del_Giappone
# level 3 - ? - Name_server
# level 3 - ? - Internet_Systems_Consortium
# level 3 - ? - .it
# level 3 - V - ICANN
# level 3 - V - IPv6
# level 3 - ? - DDNS
# level 3 - ? - Dominio_di_secondo_livello
# level 3 - ? - Database_distribuiti
# level 3 - ? - Dominio_di_primo_livello
# level 3 - V - Unix
# level 3 - ? - Risoluzione_inversa
# level 3 - ? - Record_DNS
# level 3 - V - Hypertext_Transfer_Protocol
# level 3 - ? - Record_SRV
# level 3 - ? - Inghilterra
# level 3 - ? - Università
# level 3 - ? - OpenNIC
# level 3 - ? - BIND
# level 3 - V - Internet_Protocol
# level 3 - ? - Verisign
# level 3 - ? - Svezia
# level 3 - ? - Windows_2000
# level 3 - V - Indirizzo_IP
# level 3 - ? - Jon_Postel
# level 3 - ? - NASA
# level 3 - ? - Web_server
# level 3 - ? - Record_PTR
# level 3 - ? - Anycast
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - Cybersquatting
# level 3 - ? - Point-to-Point_Protocol
# level 3 - ? - .org
# level 3 - ? - Windows
# level 3 - ? - Traceroute
# level 3 - ? - Request_for_Comments
# level 3 - ? - Base_di_dati
# level 3 - ? - Man_in_the_middle
# level 3 - ? - Nome_di_dominio_internazionalizzato
# level 3 - ? - Record_A
# level 3 - ? - Giappone
# level 3 - ? - Record_SOA
# level 3 - ? - Network_Information_Service
# level 3 - V - IPv4
# level 3 - ? - Active_Directory
# level 3 - V - Posta_elettronica
# level 3 - V - Firewall
# level 3 - ? - Unbound
# level 3 - ? - 1.1.1.1
# level 3 - ? - Phishing
# level 3 - ? - WINS
# level 3 - ? - Uniform_Resource_Locator
# level 3 - ? - Nslookup
# level 3 - ? - Acronimo
# level 3 - ? - Dynamic_DNS
# level 3 - ? - MX_record
# level 3 - V - File
# level 3 - V - Transmission_Control_Protocol
# level 3 - V - Dynamic_Host_Configuration_Protocol
# level 3 - ? - Record_CNAME
# level 3 - V - File_Transfer_Protocol
# level 3 - ? - Host
# level 3 - V - Protocollo_di_rete
# level 3 - V - Internet
# level 3 - ? - Microsoft
# level 3 - V - Server
# level 2 - ? - BOOTP
# level 3 - ? - Reverse_Address_Resolution_Protocol
# level 3 - ? - UNIX
# level 3 - ? - BIOS
# level 3 - ? - Microsoft_Windows
# level 3 - ? - Floppy_disk
# level 3 - V - Sistema_operativo
# level 3 - V - Internet_Archive
# level 3 - ? - Windows_NT
# level 3 - V - Dynamic_Host_Configuration_Protocol
# level 3 - ? - User_Datagram_Protocol
# level 3 - V - Indirizzo_IP
# level 2 - V - Ethernet
# level 2 - V - Telecomunicazioni
# level 2 - V - Controllo_della_congestione
# level 2 - ? - Maschera_di_sottorete
# level 3 - V - Internet_Protocol
# level 3 - ? - CIDR
# level 3 - V - Router
# level 3 - V - Protocollo_di_rete
# level 3 - ? - Indirizzo_di_broadcast
# level 3 - ? - Broadcasting_(informatica)
# level 3 - ? - Sottorete
# level 3 - V - Instradamento
# level 3 - ? - Address_Resolution_Protocol
# level 3 - V - Internet_Service_Provider
# level 3 - V - TCP_IP
# level 3 - V - Rete_di_calcolatori
# level 3 - ? - Classless_Inter-Domain_Routing
# level 3 - V - Traffico_(telecomunicazioni)
# level 3 - ? - Gateway_predefinito
# level 3 - ? - Configurazione_(informatica)
# level 3 - ? - Internet_Assigned_Numbers_Authority
# level 3 - ? - Gateway_(informatica)
# level 3 - ? - Host
# level 3 - V - Indirizzo_IP
# level 3 - ? - LAN
# level 3 - ? - Classi_di_indirizzi_IP
# level 3 - V - Bit
# level 2 - ? - Livello_di_trasporto
# level 3 - V - Livello_di_collegamento_dati
# level 3 - ? - Logical_link_control
# level 3 - ? - RTMP
# level 3 - V - Reti_di_calcolatori
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Modo_di_trasferimento
# level 3 - V - Controllo_della_congestione
# level 3 - ? - Stream_Control_Transmission_Protocol
# level 3 - ? - Resource_Reservation_Protocol
# level 3 - ? - Livello_di_applicazione
# level 3 - V - Transmission_Control_Protocol
# level 3 - V - Internet_Protocol
# level 3 - V - Informatica
# level 3 - ? - Livello_fisico
# level 3 - ? - Server_message_block
# level 3 - ? - User_Datagram_Protocol
# level 3 - ? - Livello_di_rete
# level 3 - V - Telecomunicazioni
# level 3 - ? - Modello_OSI
# level 3 - V - Porta_(reti)
# level 3 - ? - Controllo_di_flusso
# level 3 - ? - NetBEUI
# level 3 - ? - Commutazione_(telecomunicazioni)
# level 3 - ? - AppleTalk
# level 3 - V - Multiplazione
# level 3 - V - Modello_ISO_OSI
# level 3 - ? - Congestione_(reti)
# level 3 - ? - Host
# level 3 - V - Connessione_(informatica)
# level 3 - ? - Media_Access_Control
# level 3 - ? - Accesso_multiplo
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Comunicazione_orientata_alla_connessione
# level 3 - ? - Livello_di_presentazione
# level 3 - ? - Livello_di_sessione
# level 3 - V - Internet
# level 2 - ? - Comunicazione_senza_connessione
# level 3 - V - Protocollo_di_rete
# level 3 - ? - Broadcast
# level 3 - V - Reti_di_computer
# level 3 - ? - User_Datagram_Protocol
# level 3 - V - Commutazione_di_pacchetto
# level 3 - ? - IEEE_802.2
# level 3 - ? - Rete_(informatica)
# level 3 - ? - Unicast
# level 3 - V - Informazione
# level 3 - V - Telecomunicazioni
# level 3 - ? - Comunicazione_orientata_alla_connessione
# level 3 - V - Internet_Protocol
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - V - Connessione_(informatica)
# level 3 - V - Protocolli_di_rete
# level 3 - ? - Header
# level 3 - ? - Multicast
# level 2 - V - Sottorete
# level 2 - V - Indirizzo_MAC
# level 2 - ? - Pacchetto_(reti)
# level 3 - ? - Synchronous_Digital_Hierarchy
# level 3 - V - Multiplazione
# level 3 - ? - Livello_di_rete
# level 3 - ? - Digitale_(informatica)
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - ? - Reti_a_pacchetto
# level 3 - V - Informatica
# level 3 - ? - Protocollo_di_comunicazione
# level 3 - ? - Header
# level 3 - ? - Data_frame
# level 3 - V - Maximum_Transmission_Unit
# level 3 - V - Rete_di_telecomunicazione
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Protocol_Data_Unit
# level 3 - V - Server
# level 3 - V - Asynchronous_Transfer_Mode
# level 3 - V - Protocollo_di_rete
# level 3 - V - Ethernet
# level 3 - ? - Checksum
# level 3 - ? - Modo_di_trasferimento
# level 3 - V - Architettura_di_rete
# level 3 - V - Bit
# level 3 - V - Livello_datalink
# level 3 - ? - Livello_di_trasporto
# level 3 - V - Web
# level 3 - V - Commutazione_di_pacchetto
# level 3 - V - Suite_di_protocolli_Internet
# level 3 - V - Modello_ISO_OSI
# level 3 - ? - Byte
# level 3 - V - Informazione
# level 3 - ? - Overhead
# level 3 - ? - Plesiochronous_Digital_Hierarchy
# level 3 - V - Modulazione
# level 3 - V - RS-232
# level 3 - ? - Imbustamento
# level 3 - V - Internet_Protocol
# level 3 - ? - Client
# level 3 - V - Telecomunicazioni
# level 3 - V - TCP_IP
# level 3 - ? - Bit_stuffing
# level 3 - V - Transmission_Control_Protocol
# level 2 - V - Token_ring
# level 2 - V - Protocollo_di_rete
# level 2 - ? - Gateway_(informatica)
# level 3 - V - Indirizzo_IP
# level 3 - V - Internet
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Rete_informatica
# level 3 - V - Network_address_translation
# level 3 - ? - Reti_informatiche
# level 3 - V - Traffico_(telecomunicazioni)
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - V - Bit
# level 3 - V - Subnet
# level 3 - V - Maschera_di_sottorete
# level 3 - V - Firewall
# level 3 - V - Router
# level 3 - V - ISO_OSI
# level 3 - V - Hardware
# level 3 - V - Computer
# level 3 - V - Rete_di_telecomunicazioni
# level 3 - ? - Scheda_di_rete
# level 3 - ? - Livello_di_rete
# level 3 - V - Lingua_inglese
# level 3 - ? - Gateway_predefinito
# level 3 - V - Server
# level 3 - ? - Library_of_Congress_Control_Number
# level 3 - ? - Home_Access_Gateway
# level 3 - V - Telecomunicazione
# level 3 - V - Instradamento
# level 3 - ? - Dispositivo_di_rete
# level 3 - ? - Proxy_DNS
# level 3 - V - Access_point
# level 3 - V - Biblioteca_nazionale_di_Francia
# level 3 - V - Local_Area_Network
# level 3 - ? - Traffico
# level 3 - ? - Protocollo_di_routing
# level 3 - V - Informatica
# level 2 - V - Router
# level 2 - V - Livello_datalink
# level 2 - V - DHCP
# level 2 - V - Suite_di_protocolli_Internet
# level 2 - V - Architettura_di_rete
# level 2 - V - IPv6
# level 2 - ? - Protocollo_di_routing
# level 3 - ? - Interior_gateway_protocol
# level 3 - V - Routing_table
# level 3 - V - Router
# level 3 - ? - Livello_di_rete
# level 3 - V - Rete_locale
# level 3 - ? - Distance_vector
# level 3 - ? - IS-IS
# level 3 - ? - Link_state
# level 3 - V - Protocollo_di_rete
# level 3 - V - Internet
# level 3 - ? - Border_Gateway_Protocol
# level 3 - ? - Lingua_italiana
# level 3 - ? - Interior_Gateway_Routing_Protocol
# level 3 - ? - Amministratore_di_rete
# level 3 - V - Informatica
# level 3 - V - Telecomunicazioni
# level 3 - ? - Enhanced_Interior_Gateway_Routing_Protocol
# level 3 - ? - Ibridi
# level 3 - V - Instradamento
# level 3 - ? - Routing_Information_Protocol
# level 3 - ? - Algoritmo_di_Dijkstra
# level 3 - V - Rete_informatica
# level 3 - ? - Sistema_autonomo
# level 3 - ? - Flooding
# level 3 - ? - Exterior_Gateway_Protocol
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Open_Shortest_Path_First
# level 2 - ? - Controllo_di_flusso
# level 3 - V - Rete_di_trasporto
# level 3 - V - Informatica
# level 3 - ? - Goodput
# level 3 - ? - Commutazione
# level 3 - ? - Congestione_(reti)
# level 3 - ? - Struttura_di_controllo
# level 3 - ? - Full-duplex
# level 3 - V - Controllo_della_congestione
# level 3 - ? - Buffer_(informatica)
# level 3 - V - Programmazione_(informatica)
# level 3 - ? - Nodo_(informatica)
# level 3 - V - Transmission_Control_Protocol
# level 3 - V - Telecomunicazioni
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Traffico_(telecomunicazioni)
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - V - Connessione_(informatica)
# level 3 - V - Codice_sorgente
# level 3 - V - Rete_di_telecomunicazioni
# level 3 - ? - Processore
# level 3 - V - Protocollo_di_rete
# level 3 - ? - Host
# level 3 - V - Byte
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - ? - Library_of_Congress_Control_Number
# level 3 - V - Linguaggio_di_programmazione
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - Stack_overflow
# level 3 - ? - Programma_(informatica)
# level 3 - ? - Controllo_di_errore
# level 2 - V - Asynchronous_Transfer_Mode
# level 2 - ? - RARP
# level 3 - ? - Indirizzo_fisico
# level 3 - V - Indirizzo_IP
# level 3 - V - Dynamic_Host_Configuration_Protocol
# level 3 - V - Address_Resolution_Protocol
# level 3 - ? - Bootstrap_Protocol
# level 3 - ? - Livello_di_accesso_alla_rete
# level 3 - V - Suite_di_protocolli_Internet
# level 3 - V - Ethernet
# level 3 - ? - Broadcast
# level 3 - V - Indirizzo_MAC
# level 2 - ? - Controllo_di_errore
# level 3 - ? - Automatic_repeat_request
# level 3 - ? - Fsck
# level 3 - ? - Codifica_di_canale
# level 3 - ? - Controllo_di_congestione
# level 3 - V - Modello_OSI
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Elettronica
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - V - Rete_di_telecomunicazioni
# level 3 - ? - Bit_Error_Ratio
# level 3 - V - Informatica
# level 3 - ? - Forward_Error_Correction
# level 3 - ? - File_system
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Checkdisk
# level 3 - V - Telecomunicazioni
# level 3 - ? - Checksum
# level 3 - V - Rete_di_calcolatori
# level 3 - ? - Mezzo_trasmissivo
# level 3 - ? - Controllo_di_parità
# level 3 - V - Memoria_(informatica)
# level 3 - V - Rete_di_trasporto
# level 3 - ? - Controllo_di_flusso
# level 3 - ? - Wavelength_Division_Multiplexing
# level 2 - ? - ISO
# level 3 - ? - Saudi_Standards,_Metrology_and_Quality_Organization
# level 3 - ? - American_National_Standards_Institute
# level 3 - ? - Standardization_Administration_of_the_People's_Republic_of_China
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - ? - Japanese_Industrial_Standards
# level 3 - V - Acronimo
# level 3 - ? - Svizzera
# level 3 - ? - Lista_di_standard_ISO
# level 3 - ? - Unione_internazionale_delle_telecomunicazioni
# level 3 - V - Lingua_inglese
# level 3 - ? - ISO_45001
# level 3 - ? - Commissione_elettrotecnica_internazionale
# level 3 - ? - Virtual_International_Authority_File
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - 2019
# level 3 - ? - Norma_tecnica
# level 3 - V - Ginevra
# level 3 - ? - Componente_elettrico
# level 3 - ? - Biblioteca_della_Dieta_nazionale_del_Giappone
# level 3 - ? - ISO_9000
# level 3 - ? - ISO_31
# level 3 - ? - Sicurezza_sul_lavoro
# level 3 - ? - Organizzazione_internazionale
# level 3 - ? - Comitato_europeo_di_normazione_elettrotecnica
# level 3 - ? - ISO_9001
# level 3 - ? - Gestione_della_qualità
# level 3 - ? - Lingua_greca_antica
# level 3 - ? - Deutsches_Institut_für_Normung
# level 3 - ? - Standardizzazione_(ingegneria)
# level 3 - ? - Organizzazione_delle_Nazioni_Unite
# level 3 - ? - ISO_IEC_17025
# level 3 - ? - ISO_1
# level 3 - ? - Agency_for_Standardization,_Metrology_and_Certification_of_Uzbekistan
# level 3 - ? - Lingua_russa
# level 3 - ? - Library_of_Congress_Control_Number
# level 3 - ? - Quartier_generale
# level 3 - ? - Japanese_Industrial_Standards_Committee
# level 3 - V - Biblioteca_nazionale_di_Francia
# level 3 - ? - Comitato_europeo_di_normazione
# level 3 - V - Telecomunicazioni
# level 3 - ? - WorldCat
# level 3 - ? - Specifica_tecnica
# level 3 - ? - Associação_Brasileira_de_Normas_Técnicas
# level 3 - ? - Componente_elettronico
# level 3 - ? - Specifiche_disponibili_pubblicamente
# level 3 - ? - Unità_di_misura
# level 3 - ? - Afghanistan_National_Standards_Authority
# level 3 - ? - Abbreviazione
# level 3 - ? - National_Institute_of_Standards
# level 3 - ? - 1947
# level 3 - ? - Ente_Nazionale_Italiano_di_Unificazione
# level 3 - ? - Organizzazione_non_governativa
# level 3 - ? - ISO_14001
# level 3 - V - Londra
# level 3 - ? - International_Standard_Name_Identifier
# level 3 - ? - British_Standards_Institution
# level 3 - ? - UNESCO
# level 3 - ? - Consiglio_economico_e_sociale_delle_Nazioni_Unite
# level 3 - ? - Korean_Agency_for_Technology_and_Standards
# level 3 - ? - Lingua_francese
# level 3 - ? - Paesi_del_mondo
# level 2 - V - Instradamento
# level 2 - ? - Bootstrap_Protocol
# level 3 - V - Microsoft_Windows
# level 3 - V - Windows_NT
# level 3 - V - Dynamic_Host_Configuration_Protocol
# level 3 - V - Internet_Archive
# level 3 - V - Floppy_disk
# level 3 - ? - Reverse_Address_Resolution_Protocol
# level 3 - V - BIOS
# level 3 - V - UNIX
# level 3 - V - Sistema_operativo
# level 3 - ? - User_Datagram_Protocol
# level 3 - V - Indirizzo_IP
# level 2 - V - Address_Resolution_Protocol
# level 2 - ? - Ifconfig
# level 3 - ? - Netfilter
# level 3 - ? - Boot
# level 3 - ? - Traffic_shaping
# level 3 - ? - SSID
# level 3 - ? - FreeBSD
# level 3 - ? - Scheda_di_rete
# level 3 - V - Microsoft_Windows
# level 3 - ? - Berkeley_Software_Distribution
# level 3 - ? - Ipchains
# level 3 - V - Firewall
# level 3 - V - Maschera_di_sottorete
# level 3 - ? - MacOS
# level 3 - V - Internet
# level 3 - V - TCP_IP
# level 3 - V - Windows
# level 3 - ? - BSD
# level 3 - ? - Iproute2
# level 3 - V - Indirizzo_IP
# level 3 - ? - Kernel
# level 3 - ? - OpenBSD
# level 3 - ? - NetBSD
# level 3 - ? - Alias_IP
# level 3 - V - Ethernet
# level 3 - V - Dynamic_Host_Configuration_Protocol
# level 3 - ? - Riga_di_comando
# level 3 - V - Windows_NT
# level 3 - ? - Bootstrap_Protocol
# level 3 - V - Internet_Archive
# level 3 - ? - Route_(informatica)
# level 3 - V - Rete_(informatica)
# level 3 - ? - Shell_(informatica)
# level 3 - V - Unix
# level 3 - ? - Wrapper
# level 3 - V - UNIX
# level 3 - ? - Wired_Equivalent_Privacy
# level 3 - ? - Distribuzione_(software)
# level 3 - V - Indirizzo_MAC
# level 3 - V - Computer
# level 3 - ? - Client
# level 3 - V - Sistema_operativo
# level 3 - V - Suite_di_protocolli_Internet
# level 3 - ? - Windows_95
# level 3 - ? - Distribuzione_Linux
# level 3 - V - Wireless
# level 3 - ? - Linux
# level 3 - ? - Script
# level 3 - V - Microsoft
# level 3 - ? - Windows_Me
# level 3 - ? - Unix-like
# level 3 - ? - Man_(Unix)
# level 2 - V - Reti_di_calcolatori
# level 2 - V - Shell_(informatica)
# level 2 - ? - Host
# level 3 - ? - Kazaa
# level 3 - ? - Napster
# level 3 - V - Maschera_di_sottorete
# level 3 - ? - Scheda_di_rete
# level 3 - V - Web_server
# level 3 - ? - Peer_to_peer
# level 3 - ? - Workstation
# level 3 - ? - Palmari
# level 3 - ? - EMule
# level 3 - V - DNS
# level 3 - V - Lingua_inglese
# level 3 - ? - Livello_applicazioni
# level 3 - V - Computer
# level 3 - ? - Gateway_(informatica)
# level 3 - ? - Thin_client
# level 3 - ? - Elaborazione_dati
# level 3 - V - Internet_Protocol
# level 3 - ? - Direct_Connect
# level 3 - V - Internet
# level 3 - V - Router
# level 3 - ? - Client
# level 3 - V - DHCP
# level 3 - ? - Computer_desktop
# level 3 - V - Stampante
# level 3 - V - Informatica
# level 3 - ? - Amministratore_di_rete
# level 3 - V - Browser
# level 3 - V - Switch
# level 3 - V - Indirizzo_IP
# level 3 - ? - Web_TV
# level 3 - ? - Host_Identity_Protocol
# level 3 - V - E-mail
# level 3 - V - Terminale_(informatica)
# level 3 - V - Indirizzo_MAC
# level 3 - ? - Dispositivi_mobili
# level 3 - ? - Sistemista
# level 3 - V - Server
# level 3 - V - LAN
# level 2 - ? - Livello_di_collegamento
# level 3 - V - Reti_di_calcolatori
# level 3 - ? - Controllo_di_errore
# level 3 - V - Codifica_di_canale
# level 3 - V - Multiplazione
# level 3 - ? - Controller_Area_Network
# level 3 - ? - Trasmissione_seriale_asincrona
# level 3 - ? - Media_Access_Control
# level 3 - ? - Frame_Relay
# level 3 - ? - Pacchetto_(reti)
# level 3 - ? - Controllo_di_flusso
# level 3 - V - Architettura_di_rete
# level 3 - V - X.25
# level 3 - ? - Procedure_avanzate_di_controllo_della_comunicazione_dati
# level 3 - ? - IEEE_802.3
# level 3 - V - LAN
# level 3 - ? - IEEE_802.11
# level 3 - ? - Livello_di_presentazione
# level 3 - V - ISO_OSI
# level 3 - ? - Network_Driver_Interface_Specification
# level 3 - V - IEEE_802.2
# level 3 - V - Telecomunicazioni
# level 3 - ? - Banda_(informatica)
# level 3 - ? - CSMA_CA
# level 3 - ? - Buffer_overflow
# level 3 - ? - Interferenza_(telecomunicazioni)
# level 3 - V - Sistema_operativo
# level 3 - V - Token_ring
# level 3 - ? - FDDI
# level 3 - ? - Stop-and-wait_ARQ
# level 3 - V - Acronimo
# level 3 - V - Protocollo_di_rete
# level 3 - ? - CSMA_CD
# level 3 - V - Address_Resolution_Protocol
# level 3 - V - Modello_OSI
# level 3 - V - WiFi
# level 3 - ? - High-Level_Data_Link_Control
# level 3 - ? - HDLC
# level 3 - V - Modello_ISO_OSI
# level 3 - ? - Medium_Access_Control
# level 3 - V - Livello_datalink
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - ? - Mezzo_fisico
# level 3 - ? - Checksum
# level 3 - ? - Multiprotocol_Label_Switching
# level 3 - ? - Cyclic_redundancy_check
# level 3 - ? - Accesso_multiplo
# level 3 - ? - Livello_fisico
# level 3 - V - Organizzazione_Internazionale_per_le_Standardizzazioni
# level 3 - ? - IEEE_802
# level 3 - ? - Imbustamento
# level 3 - ? - Mezzo_trasmissivo
# level 3 - ? - ARCnet
# level 3 - ? - Livello_di_trasporto
# level 3 - ? - Scheda_di_rete
# level 3 - ? - Logical_link_control
# level 3 - ? - Codifica_di_canale#ARQ_(Automatic_Repeat-reQuest)
# level 3 - ? - Codice_di_Hamming
# level 3 - ? - Point-to-Point_Protocol
# level 3 - ? - Shortest_Path_Bridging
# level 3 - ? - Livello_di_applicazione
# level 3 - ? - Acknowledgment
# level 3 - ? - Header
# level 3 - ? - Cisco_Discovery_Protocol
# level 3 - ? - Piggyback
# level 3 - ? - ACK_(informatica)
# level 3 - ? - WLAN
# level 3 - V - Standard_(informatica)
# level 3 - ? - Amiga
# level 3 - ? - Forward_Error_Correction
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Livello_di_rete
# level 3 - ? - Broadcasting_(informatica)
# level 3 - V - Indirizzo_MAC
# level 3 - V - Ethernet
# level 3 - ? - Rete_a_pacchetto
# level 3 - ? - Latenza
# level 3 - ? - Trasmissione_seriale_sincrona
# level 3 - ? - Wireless_LAN
# level 3 - V - Software
# level 3 - V - Asynchronous_Transfer_Mode
# level 3 - ? - Livello_di_sessione
# level 3 - V - Management_di_rete
# level 3 - ? - Campo_(informatica)
# level 3 - ? - Driver
# level 3 - ? - Trasmissione_seriale
# level 3 - V - ASCII
# level 3 - ? - Data_frame#Frame
# level 3 - ? - Serial_Line_Internet_Protocol
# level 3 - ? - Bit_(informatica)
# level 3 - ? - Data_frame
# level 2 - ? - Protocolli_di_routing
# level 3 - V - Instradamento
# level 3 - V - Protocollo_di_rete
# level 3 - ? - Flooding
# level 3 - V - Internet
# level 3 - V - Border_Gateway_Protocol
# level 3 - V - Routing_table
# level 3 - V - Routing_Information_Protocol
# level 3 - V - Informatica
# level 3 - ? - Interior_gateway_protocol
# level 3 - ? - Lingua_italiana
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Telecomunicazioni
# level 3 - ? - Interior_Gateway_Routing_Protocol
# level 3 - ? - IS-IS
# level 3 - ? - Livello_di_rete
# level 3 - V - Algoritmo_di_Dijkstra
# level 3 - V - Enhanced_Interior_Gateway_Routing_Protocol
# level 3 - ? - Sistema_autonomo
# level 3 - ? - Exterior_Gateway_Protocol
# level 3 - V - Router
# level 3 - ? - Distance_vector
# level 3 - V - Open_Shortest_Path_First
# level 3 - V - Rete_locale
# level 3 - V - Ibridi
# level 3 - ? - Amministratore_di_rete
# level 3 - V - Rete_informatica
# level 3 - ? - Link_state
# level 2 - V - Informatica
# level 2 - V - IPv4
# level 2 - V - Transmission_Control_Protocol
# level 2 - V - Modello_OSI
# level 2 - ? - Best_effort
# level 3 - ? - QoS
# level 3 - ? - Traffic_shaping
# level 3 - V - VoIP
# level 3 - ? - SMS
# level 3 - V - Rete_di_telecomunicazioni
# level 3 - V - Internet
# level 2 - ? - Point-to-Point_Protocol
# level 3 - V - GPRS
# level 3 - V - Indirizzo_IP
# level 3 - ? - Frame_Check_Sequence
# level 3 - V - Livello_di_collegamento_dati
# level 3 - ? - Library_of_Congress_Control_Number
# level 3 - V - DSL
# level 3 - ? - 1990
# level 3 - V - Modello_OSI
# level 3 - ? - Challenge-Handshake_Authentication_Protocol
# level 3 - ? - Data_frame
# level 3 - ? - Extensible_Authentication_Protocol
# level 3 - ? - DIAMETER
# level 3 - V - Protocollo_di_rete
# level 3 - V - HDLC
# level 3 - V - Ethernet
# level 3 - V - Modello_ISO_OSI
# level 3 - ? - RADIUS
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - ? - Scheda_di_rete
# level 3 - ? - PPPoA
# level 3 - V - Internet
# level 3 - V - Asynchronous_Transfer_Mode
# level 3 - V - Wide_Area_Network
# level 3 - ? - AppleTalk
# level 3 - ? - Magic_number
# level 3 - V - Informatica
# level 3 - ? - Gateway_(informatica)
# level 3 - V - Internet_Protocol
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Checksum
# level 3 - V - Computer
# level 3 - ? - Serial_Line_Internet_Protocol
# level 3 - ? - L2TP
# level 3 - ? - Internet_Engineering_Task_Force
# level 3 - ? - PPPoE
# level 3 - V - Internet_Service_Provider
# level 3 - V - Livello_datalink
# level 3 - V - Dynamic_Host_Configuration_Protocol
# level 3 - ? - Internetwork_Packet_Exchange
# level 3 - ? - Pppd
# level 2 - ? - Livello_di_rete
# level 3 - ? - Logical_link_control
# level 3 - V - Asynchronous_Transfer_Mode
# level 3 - ? - Livello_di_sessione
# level 3 - V - X.25
# level 3 - V - Wide_Area_Network
# level 3 - V - ISO_OSI
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Commutazione_(telecomunicazioni)
# level 3 - ? - Livello_di_trasporto
# level 3 - ? - Frammentazione_(informatica)
# level 3 - V - Connessione_(informatica)
# level 3 - ? - Livello_di_applicazione
# level 3 - V - Tabella_di_routing
# level 3 - V - Instradamento
# level 3 - V - Indirizzo_IP
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Internetwork_Packet_Exchange
# level 3 - V - Internet_Protocol
# level 3 - ? - Protocolli_di_routing
# level 3 - V - Router
# level 3 - ? - Media_Access_Control
# level 3 - ? - Livello_fisico
# level 3 - ? - Comunicazione_orientata_alla_connessione
# level 3 - V - Suite_di_protocolli_Internet
# level 3 - ? - Frame_Relay
# level 3 - ? - Livello_di_presentazione
# level 3 - ? - Comunicazione_senza_connessione
# level 3 - V - Reti_di_calcolatori
# level 3 - V - Rete_informatica
# level 3 - V - Border_Gateway_Protocol
# level 3 - V - Informatica
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Controllo_della_congestione
# level 3 - V - Qualità_di_servizio
# level 3 - ? - Point-to-Point_Protocol
# level 3 - V - Ethernet
# level 3 - ? - Metropolitan_Area_Network
# level 3 - V - Routing_Information_Protocol
# level 3 - ? - Host
# level 3 - V - Livello_di_collegamento_dati
# level 3 - V - Switch
# level 3 - V - Livello_datalink
# level 3 - V - Open_Shortest_Path_First
# level 3 - V - Telecomunicazioni
# level 3 - ? - Algoritmi
# level 3 - V - Modello_OSI
# level 3 - ? - Protocollo_di_routing
# level 2 - ? - PowerShell
# level 3 - ? - Windows_Server_2003
# level 3 - ? - X86
# level 3 - ? - Registro_di_Windows
# level 3 - V - Sito_web
# level 3 - ? - MS-DOS
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - ? - Microsoft_.NET
# level 3 - ? - Awk
# level 3 - V - Linux
# level 3 - ? - Korn_shell
# level 3 - ? - Armonia_prestabilita
# level 3 - V - Microsoft
# level 3 - ? - Linguaggio_di_scripting
# level 3 - V - Unix
# level 3 - ? - Wrapper
# level 3 - ? - Cmd.exe
# level 3 - ? - Open_source
# level 3 - ? - Licenza_(informatica)
# level 3 - V - Software
# level 3 - V - Virus_(informatica)
# level 3 - ? - Command.com
# level 3 - ? - Monadologia
# level 3 - ? - Library_of_Congress_Control_Number
# ...
# level 3 - V - Connessione_(informatica)
# level 3 - V - Ethernet
# level 3 - V - Dispositivo_di_rete
# level 3 - ? - Livello_di_rete
# level 3 - V - Software
# level 3 - V - Frammentazione_(informatica)
# level 3 - V - Cavo_elettrico
# level 3 - ? - Trama
# level 3 - V - Informazione
# level 3 - ? - Carico_utile_(informatica)
# level 3 - V - Architettura_di_rete
# level 3 - V - Internet_Protocol
# level 3 - V - Telecomunicazioni
# level 3 - ? - Pagina_web
# level 3 - V - Commutazione_di_pacchetto
# level 3 - V - Indirizzo_IP
# level 3 - ? - HTML
# level 3 - V - Porta_(reti)
# level 3 - V - Transmission_Control_Protocol
# level 3 - V - Hypertext_Transfer_Protocol
# level 3 - ? - Service_Data_Unit
# level 3 - ? - Mezzo_trasmissivo
# level 3 - ? - Checksum
# level 3 - ? - Tunneling
# level 2 - ? - Livello_di_rete
# level 3 - ? - Livello_di_applicazione
# level 3 - V - Canale_(telecomunicazioni)
# level 3 - ? - Nodo_(informatica)
# level 3 - ? - Frame_Relay
# level 3 - V - Internet_Protocol
# level 3 - V - Frammentazione_(informatica)
# level 3 - ? - Livello_di_presentazione
# level 3 - V - Modello_OSI
# level 3 - ? - Comunicazione_orientata_alla_connessione
# level 3 - V - Connessione_(informatica)
# level 3 - ? - Livello_di_trasporto
# level 3 - V - Algoritmi
# level 3 - V - Router
# level 3 - V - Tabella_di_routing
# level 3 - V - Rete_informatica
# level 3 - ? - Internetwork_Packet_Exchange
# level 3 - V - Indirizzo_IP
# level 3 - V - Asynchronous_Transfer_Mode
# level 3 - V - Border_Gateway_Protocol
# level 3 - V - Wide_Area_Network
# level 3 - V - Routing_Information_Protocol
# level 3 - ? - Pacchetto_(reti)
# level 3 - V - Open_Shortest_Path_First
# level 3 - ? - Commutazione_(telecomunicazioni)
# level 3 - V - Livello_di_collegamento_dati
# level 3 - ? - Livello_di_sessione
# level 3 - V - Qualità_di_servizio
# level 3 - ? - Logical_link_control
# level 3 - ? - Point-to-Point_Protocol
# level 3 - V - Reti_di_calcolatori
# level 3 - V - Informatica
# level 3 - V - ISO_OSI
# level 3 - V - Instradamento
# level 3 - V - Telecomunicazioni
# level 3 - ? - Livello_fisico
# level 3 - V - Controllo_della_congestione
# level 3 - ? - Media_Access_Control
# level 3 - ? - Host
# level 3 - ? - Comunicazione_senza_connessione
# level 3 - V - Ethernet
# level 3 - ? - Metropolitan_Area_Network
# level 3 - V - X.25
# level 3 - ? - Protocollo_di_routing
# level 3 - V - Livello_datalink
# level 3 - V - Suite_di_protocolli_Internet
# level 3 - V - Switch
# level 3 - ? - Protocolli_di_routing
# level 2 - V - Plesiochronous_Digital_Hierarchy
# level 2 - V - Architettura_di_rete
# level 1 - V - Streaming
# level 1 - ? - Intrusione_nel_segnale_di_broadcasting
# level 2 - ? - HBO#La_protesta_di_.22Captain_Midnight.22
# level 3 - ? - The_Seekers
# level 3 - V - Stati_Uniti_d'America
# level 3 - ? - Boardwalk_Empire_-_L'impero_del_crimine
# level 3 - ? - The_Larry_Sanders_Show
# level 3 - ? - Barry_(serie_televisiva)
# level 3 - ? - Mildred_Pierce_(miniserie_televisiva)
# level 3 - ? - Foo_Fighters:_Sonic_Highways
# level 3 - ? - Il_seggio_vacante_(miniserie_televisiva)
# level 3 - ? - Anthony,_formidabile_formica
# level 3 - ? - 1972
# level 3 - ? - Mosaic_(videogioco)
# level 3 - ? - Fraggle_Rock
# level 3 - ? - Home_Box_Office_(azienda)
# level 3 - ? - Vice_Principals
# level 3 - ? - The_Leftovers_-_Svaniti_nel_nulla
# level 3 - ? - Pugilato
# level 3 - ? - Il_Trono_di_Spade_(serie_televisiva)
# level 3 - ? - Girls_(serie_televisiva)
# level 3 - ? - Enlightened
# level 3 - V - Televisione_satellitare
# level 3 - ? - Tales_from_the_Crypt
# level 3 - ? - Unscripted
# level 3 - ? - Il_gioco_del_falco
# level 3 - ? - Family_Channel
# level 3 - ? - The_Last_of_Us_(serie_televisiva)
# level 3 - ? - Last_Week_Tonight_with_John_Oliver
# level 3 - ? - Sesamo_apriti
# level 3 - ? - Stuart_Little_(serie_animata)
# level 3 - ? - PBS_(azienda)
# level 3 - ? - Curb_Your_Enthusiasm
# level 3 - ? - The_Young_Pope
# level 3 - ? - Chernobyl_(miniserie_televisiva)
# level 3 - ? - Insecure
# level 3 - ? - Togetherness_(serie_televisiva)
# level 3 - V - Biblioteca_nazionale_di_Francia
# level 3 - ? - Crashing_(serie_televisiva_2017)
# level 3 - ? - Un_amore_senza_tempo_-_The_Time_Traveler's_Wife
# level 3 - ? - The_New_Pope
# level 3 - ? - Warner_Bros._Discovery
# level 3 - ? - Angels_in_America
# level 3 - ? - Sky_(azienda)
# level 3 - ? - HDTV
# level 3 - ? - Vinyl_(serie_televisiva)
# level 3 - ? - One_Night_Stand
# level 3 - ? - The_Outsider_(miniserie_televisiva)
# level 3 - ? - The_Newsroom_(serie_televisiva_2012)
# level 3 - V - Documentario
# level 3 - ? - I_Soprano
# level 3 - ? - Oz_(serie_televisiva)
# level 3 - ? - Entourage_(serie_televisiva)
# level 3 - V - Emittente_televisiva
# level 3 - ? - I_May_Destroy_You_-_Trauma_e_rinascita
# level 3 - ? - John_Adams_(miniserie_televisiva)
# level 3 - ? - Abbonamento
# level 3 - ? - Getting_On_(serie_televisiva_2013)
# level 3 - ? - Vlaamse_Radio-_en_Televisieomroep
# level 3 - ? - Big_Little_Lies_-_Piccole_grandi_bugie
# level 3 - ? - Elizabeth_I
# level 3 - ? - Lovecraft_Country_-_La_terra_dei_demoni
# level 3 - ? - Lungometraggio
# level 3 - ? - Room_104
# level 3 - ? - The_Comeback
# level 3 - ? - Tsunami_(miniserie_televisiva)
# level 3 - ? - CBS
# level 3 - ? - 480i
# level 3 - ? - La_storia_infinita_(serie_animata)
# level 3 - ? - Here_and_Now_-_Una_famiglia_americana
# level 3 - ? - Emily_&_Alexander,_che_tipi_questi_topi
# level 3 - ? - Show_Me_a_Hero
# level 3 - ? - Universal_Television
# level 3 - ? - Spicy_City
# level 3 - ? - The_Pacific
# level 3 - ? - Canal+
# level 3 - ? - Dalla_Terra_alla_Luna_(miniserie_televisiva)
# level 3 - ? - Six_Feet_Under
# level 3 - ? - SDTV
# level 3 - ? - Treme
# level 3 - ? - WorldCat
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - ? - Dream_On_(serie_televisiva)
# level 3 - ? - Succession
# level 3 - ? - Sharp_Objects
# level 3 - ? - The_Ricky_Gervais_Show_(serie_animata)
# level 3 - ? - L'amica_geniale_(serie_televisiva)
# level 3 - ? - Perry_Mason_(serie_televisiva_2020)
# level 3 - ? - Caterina_la_Grande_(miniserie_televisiva)
# level 3 - ? - Omicidio_a_Easttown
# level 3 - ? - Divorce_(serie_televisiva)
# level 3 - ? - Sky_Atlantic_(Regno_Unito)
# level 3 - ? - Ballers
# level 3 - ? - Roma_(serie_televisiva)
# level 3 - ? - Da_Ali_G_Show
# level 3 - ? - Serie_televisiva
# level 3 - ? - Five_Days_(serie_televisiva)
# level 3 - ? - Florida
# level 3 - ? - Eastbound_&_Down
# level 3 - ? - Hello_Ladies
# level 3 - ? - I_Spy
# level 3 - ? - Bravo_(rete_televisiva)
# level 3 - ? - John_from_Cincinnati
# level 3 - ? - Pay_TV
# level 3 - ? - True_Blood
# level 3 - ? - 1080i
# level 3 - ? - Mrs._Fletcher
# level 3 - ? - We_Own_This_City_-_Potere_e_corruzione
# level 3 - ? - Sally4Ever
# level 3 - ? - Happily_Ever_After:_Fairy_Tales_for_Every_Child
# level 3 - V - Satellite_artificiale
# level 3 - ? - Avenue_5
# level 3 - ? - The_No._1_Ladies'_Detective_Agency
# level 3 - ? - Channel_4
# level 3 - ? - Dollaro_statunitense
# level 3 - ? - Camera_d'albergo_(Hotel_Room)
# level 3 - ? - USA_Network
# level 3 - ? - Australian_Broadcasting_Corporation
# level 3 - ? - Tales_from_the_Neverending_Story
# level 3 - ? - Un_volto,_due_destini_-_I_Know_This_Much_Is_True
# level 3 - ? - Philip_Marlowe,_detective_privato
# level 3 - ? - The_White_Lotus
# level 3 - ? - Silicon_Valley_(serie_televisiva)
# level 3 - ? - Messaggio
# level 3 - ? - I_ribelli_(programma_televisivo)
# level 3 - ? - The_Undoing_-_Le_verità_non_dette
# level 3 - ? - The_Nevers
# level 3 - ? - Olive_Kitteridge_(miniserie_televisiva)
# level 3 - ? - Arliss
# level 3 - ? - Hung_-_Ragazzo_squillo
# level 3 - ? - Sex_and_the_City
# level 3 - ? - Rai_Fiction
# level 3 - ? - Lucky_Louie
# level 3 - ? - In_Treatment
# level 3 - ? - The_Movie_Network
# level 3 - ? - Televisione_via_cavo
# level 3 - ? - Global
# level 3 - ? - Looking
# level 3 - ? - Statunitense
# level 3 - ? - Virtual_International_Authority_File
# level 3 - ? - I_viaggiatori_delle_tenebre
# level 3 - ? - Empire_Falls
# level 3 - ? - Winning_Time_-_L'ascesa_della_dinastia_dei_Lakers
# level 3 - ? - 1986
# level 3 - ? - Luck_(serie_televisiva)
# level 3 - ? - Parade's_End
# level 3 - ? - Crashbox
# level 3 - ? - How_to_Make_It_in_America
# level 3 - ? - NFL_Films
# level 3 - V - Antenna
# level 3 - ? - 1999
# level 3 - ? - Westworld_-_Dove_tutto_è_concesso
# level 3 - ? - The_Wire_(serie_televisiva)
# level 3 - ? - Deadwood_(serie_televisiva)
# level 3 - ? - Gentleman_Jack_-_Nessuna_mi_ha_mai_detto_di_no
# level 3 - ? - La_Cinq
# level 3 - ? - Angry_Boys
# level 3 - ? - The_Gilded_Age_(serie_televisiva)
# level 3 - ? - Veep_-_Vicepresidente_incompetente
# level 3 - ? - Standing_Room_Only
# level 3 - ? - Watchmen_(miniserie_televisiva)
# level 3 - ? - The_Little_Lulu_Show
# level 3 - ? - The_Night_Of
# level 3 - ? - ITV_(rete_televisiva)
# level 3 - ? - YTV_(rete_televisiva)
# level 3 - ? - The_Life_&_Times_of_Tim
# level 3 - ? - The_Mind_of_the_Married_Man
# level 3 - ? - BBC
# level 3 - ? - Generation_Kill_(miniserie_televisiva)
# level 3 - ? - Concerto
# level 3 - ? - Tell_Me_You_Love_Me_-_Il_sesso._La_vita
# level 3 - ? - CBC_Television
# level 3 - ? - Run_-_Fuga_d'amore
# level 3 - ? - His_Dark_Materials_-_Queste_oscure_materie
# level 3 - ? - High_Maintenance_(serie_televisiva)
# level 3 - ? - The_Kids_in_the_Hall
# level 3 - ? - Euphoria_(serie_televisiva)
# level 3 - ? - House_of_the_Dragon
# level 3 - ? - True_Detective
# level 3 - ? - Years_and_Years
# level 3 - ? - International_Standard_Name_Identifier
# level 3 - ? - The_Brink_(serie_televisiva)
# level 3 - ? - Stand-up_comedy
# level 3 - ? - Film_per_la_televisione
# level 3 - ? - Showtime_(rete_televisiva)
# level 3 - ? - Sky_Atlantic_(Italia)
# level 3 - ? - Animals_(serie_animata)
# level 3 - ? - Carnivàle
# level 3 - ? - Flight_of_the_Conchords
# level 3 - ? - Bored_to_Death_-_Investigatore_per_noia
# level 3 - ? - Family_Tree_(serie_televisiva)
# level 3 - ? - Big_Love
# level 3 - ? - Extras_(serie_televisiva)
# level 3 - ? - The_Jinx_-_La_vita_e_le_morti_di_Robert_Durst
# level 3 - V - Lingua_inglese
# level 3 - ? - Irma_Vep_-_La_vita_imita_l'arte
# level 3 - ? - Band_of_Brothers_-_Fratelli_al_fronte
# level 3 - ? - The_Deuce_-_La_via_del_porno
# level 3 - ? - Set-top_box#Tipologie
# level 3 - ? - Kindergarten
# level 3 - ? - Life's_Too_Short
# level 3 - ? - Spawn_(serie_animata)
# level 2 - ? - Emittenti_radiofoniche
# level 3 - V - Nuovo_soggettario
# level 3 - ? - Regista
# level 3 - ? - Metonimia
# level 3 - V - Internet
# level 3 - ? - Giornalista_pubblicista
# level 3 - V - Mezzo_di_comunicazione_di_massa
# level 3 - ? - Broadcasting
# level 3 - ? - Italia
# level 3 - V - Radio_(mass_media)
# level 3 - ? - Diretta
# level 3 - V - Ampiezza_di_banda
# level 3 - V - E-mail
# level 3 - V - Sistema_real-time
# level 3 - ? - Library_of_Congress_Control_Number
# level 3 - V - Antenna_a_dipolo
# level 3 - ? - Telediffusione
# level 3 - V - Messaggistica_istantanea
# level 3 - V - Pubblicità
# level 3 - V - Suono
# level 3 - V - Business
# level 3 - V - Gemeinsame_Normdatei
# level 3 - V - Telecomunicazioni
# level 3 - ? - Emittenti_radiofoniche_internazionali_in_lingua_italiana
# level 3 - ? - Biblioteca_nazionale_di_Israele
# level 3 - V - Rete_di_calcolatori
# level 3 - V - Editore
# level 3 - V - Canzone_(musica)
# level 3 - V - Mondo
# level 3 - V - Palinsesto_(mass_media)
# level 3 - V - Trasmissione_(telecomunicazioni)
# level 3 - V - Pubblico_(spettacolo)
# level 3 - V - Territorio
# level 3 - ? - Biblioteca_della_Dieta_nazionale_del_Giappone
# level 3 - V - Biblioteca_nazionale_di_Francia
# level 3 - V - Nazione
# level 3 - V - Musica
# level 3 - V - Azienda
# level 3 - V - Anni_1990
# level 3 - ? - Trasmissione_analogica
# level 3 - V - Segnale_(fisica)
# level 3 - ? - Trasmissione_digitale
# level 3 - ? - Conduttore_radiofonico
# level 3 - V - Bilancio_d'esercizio
# level 3 - V - SMS
# level 2 - ? - USA
# level 3 - ? - Repubblica_del_Texas
# level 3 - ? - Piedmont_(Stati_Uniti_d'America)
# level 3 - ? - VIII_Giochi_olimpici_invernali
# level 3 - ? - Giapponesi
# level 3 - ? - Scozzesi
# level 3 - ? - Primavera_silenziosa
# level 3 - V - Gemeinsame_Normdatei
# level 3 - ? - Barack_Obama
# level 3 - ? - Joseph_Henry
# level 3 - ? - Nazionale_di_rugby_a_15_femminile_degli_Stati_Uniti_d'America
# level 3 - ? - Tutti_gli_uomini_sono_stati_creati_uguali
# level 3 - ? - Norman_Joseph_Woodland
# level 3 - ? - Giochi_della_X_Olimpiade
# level 3 - ? - Neodarwinismo
# level 3 - ? - Elezioni_primarie
# level 3 - ? - Elisha_Gray
# level 3 - ? - Harold_Urey
# level 3 - ? - Nuovi_Paesi_Bassi
# level 3 - ? - Kamala_Harris
# level 3 - ? - Tredici_colonie
# level 3 - ? - John_von_Neumann
# level 3 - ? - Chiesa_cattolica
# level 3 - ? - Clifford_Shull
# level 3 - ? - Impero_coloniale_francese
# level 3 - ? - Ub_Iwerks
# level 3 - ? - National_Oceanic_and_Atmospheric_Administration
# level 3 - ? - Irving_Langmuir
# level 3 - ? - Oceania
# level 3 - ? - Lingua_hawaiiana
# level 3 - ? - Virginia_Occidentale
# level 3 - ? - Minnesota
# level 3 - ? - Imperialismo_culturale
# level 3 - ? - Conservatorismo
# level 3 - ? - Potenze_dell'Asse
# level 3 - ? - Immigrazione_negli_Stati_Uniti_d'America
# level 3 - ? - CIA
# level 3 - V - Los_Angeles
# level 3 - ? - 113º_Congresso_degli_Stati_Uniti_d'America#Regolamento
# level 3 - ? - 7_dicembre
# level 3 - ? - Reggiseno
# level 3 - ? - Isola_Howland
# level 3 - V - Norvegia
# level 3 - ? - Theodore_Harold_Maiman
# level 3 - ? - Kentucky
# level 3 - ? - Pennsylvania
# level 3 - ? - Calvinismo
# level 3 - ? - Reddito_pro_capite
# level 3 - ? - Sottomarino_nucleare
# level 3 - ? - Razzismo_negli_Stati_Uniti_d'America
# level 3 - ? - Golfo_del_Messico
# level 3 - ? - Area
# level 3 - ? - Droga
# level 3 - ? - Il_giovane_Holden
# level 3 - ? - Lampadina
# level 3 - ? - Europa_orientale
# level 3 - ? - Campionato_mondiale_di_calcio_femminile
# level 3 - ? - Ciclone_tropicale
# level 3 - ? - Turchi
# level 3 - ? - Apollo_11
# level 3 - ? - John_Harvard
# level 3 - ? - United_States_Army_Reserve
# level 3 - ? - Telefono
# level 3 - ? - Premio_Nobel_per_la_fisica
# level 3 - ? - Lingua_nazionale
# level 3 - ? - Rugby_a_15
# level 3 - ? - Tennessee
# level 3 - ? - Vulcano
# level 3 - ? - Regno_di_Gran_Bretagna
# level 3 - ? - Walter_Houser_Brattain
# level 3 - ? - Claymation
# level 3 - ? - Organizzazione_del_Trattato_dell'Atlantico_del_Nord
# level 3 - ? - Attentato_di_Sarajevo
# level 3 - ? - Uomo_Ragno
# level 3 - ? - Buddhismo
# level 3 - ? - Federal_Bureau_of_Investigation
# level 3 - ? - Appalachi
# level 3 - ? - Guerre_jugoslave
# level 3 - ? - Iowa
# level 3 - ? - Teoria_della_parità_dei_poteri_di_acquisto
# level 3 - V - Utah
# level 3 - V - Canada
# level 3 - ? - Alfred_Hitchcock
# level 3 - ? - Isola_Baker
# level 3 - ? - La_famiglia_Addams
# level 3 - ? - Alexander_Calder
# level 3 - ? - Worldwatch_Institute
# level 3 - ? - Batman
# level 3 - ? - Robert_Fulton
# level 3 - ? - Isole_Vergini_britanniche
# level 3 - ? - George_Heilmeier
# level 3 - ? - Cartone_animato
# level 3 - ? - XIX_Giochi_olimpici_invernali
# level 3 - ? - Fauna
# level 3 - ? - Codice_a_barre
# level 3 - ? - AmeriCorps_VISTA
# level 3 - V - Coordinate_geografiche
# level 3 - ? - Walt_Disney
# level 3 - ? - Superpotenza
# level 3 - ? - Azione_positiva
# level 3 - ? - Danza_moderna
# level 3 - ? - Progetto_Manhattan
# level 3 - ? - 1876
# level 3 - ? - Transistor
# level 3 - ? - Agenzia_per_la_protezione_dell'ambiente
# level 3 - ? - Sudan
# level 3 - ? - Nelly_Korda
# level 3 - ? - Carl_David_Anderson
# level 3 - ? - Danesi
# level 3 - ? - Lance_Armstrong
# level 3 - ? - Nave_da_battaglia
# level 3 - ? - Indie_occidentali_danesi
# level 3 - ? - 1865
# level 3 - ? - Prima_guerra_mondiale
# level 3 - ? - Luis_Álvarez
# level 3 - ? - Corsa_all'oro_del_Klondike
# level 3 - ? - Filippine
# level 3 - ? - Jimmy_Carter
# level 3 - ? - Moby_Dick
# level 3 - ? - Indy_Racing_League
# level 3 - ? - Gran_Bacino
# level 3 - ? - Parco_Nazionale_di_Yellowstone
# level 3 - ? - Portoghesi
# level 3 - ? - Sigla
# level 3 - ? - Bioetica
# level 3 - ? - Greater_Los_Angeles_Area
# level 3 - ? - Campagna_di_Polonia
# level 3 - ? - Clima_alpino
# level 3 - ? - Wyoming
# level 3 - ? - Jack_Kerouac
# level 3 - ? - Volstead_Act
# level 3 - ? - Soia
# level 3 - ? - Guam
# level 3 - ? - Elezioni_presidenziali_negli_Stati_Uniti_d'America
# level 3 - ? - Repubblica_federale
# level 3 - ? - Robert_Schrieffer
# level 3 - ? - Colonizzazione_europea_delle_Americhe
# level 3 - V - Musica
# level 3 - ? - Miami-Dade_Police_Department
# level 3 - ? - DuPont
# level 3 - ? - Olandesi
# level 3 - ? - Washington_(stato)
# level 3 - ? - Nazionale_di_pallacanestro_degli_Stati_Uniti_d'America
# level 3 - ? - Alcide_De_Gasperi
# level 3 - ? - Maine
# level 3 - ? - Riserva_militare
